# %% [markdown]
# # Magic Function

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(5,5,'o')
plt.show()

# %%
plt.title("Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# %matplotlib notebook

# %%
plt.plot(5,5,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title("Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
